# %% [markdown]
# # EDA Inicial: Obras e BoM
# Exploração dos dados de obras e Bill of Materials (BoM).

# %%
import pandas as pd
# Carregar dados
df = pd.read_csv('../data/obras.csv')  # ajuste o nome do arquivo conforme necessário
df.head()

# %% [markdown]
# ## Informações Gerais
# Visualize o tamanho do dataset e tipos de dados.

# %%
df.info()
df.describe()

# %% [markdown]
# ## Análise de valores ausentes
# Verifique colunas com dados faltantes.

# %%
df.isnull().sum()

# %% [markdown]
# ## Distribuição das principais variáveis
# Exemplo: custo_total, prazo_dias, n_itens_bom.

# %%
import matplotlib.pyplot as plt
df['custo_total'].hist(bins=20)
plt.title('Distribuição do Custo Total')
plt.xlabel('Custo Total')
plt.ylabel('Frequência')
plt.show()
